# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../../data/location_id_mapping.csv')
data = data.drop_duplicates(keep='first').dropna().reset_index(drop=True)
data.to_csv('../../data/location_id_mapping.csv', index=False)
